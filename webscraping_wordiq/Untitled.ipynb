# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
posts = []
#for i in range(2,50):
headers = {'Content-Type': 'application/x-www-form-urlencoded',
           'Origin': 'https://www.youtube.com',
           'Referer': 'https://www.youtube.com/watch?v=rqYdxXfBKeY',
           'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.130 Safari/537.36'
           }
data = {'session_token':'',
        'client_url':'https://www.youtube.com/watch?v=rqYdxXfBKeY'}

req = requests.post(
    url='https://www.youtube.com/watch_fragments_ajax?watch_fragments_ajax?v=rqYdxXfBKeY&tr=scroll&distiller=1&frags=comments&spf=load',
    headers=headers,
    data = data
)

bs = BeautifulSoup(req.text, "html.parser")
text = bs.findAll('div', {'class': 'comment-text-content'})
posts.extend(text)

# %%
req
# Out:
# <Response [403]>

# %%
re.sub('<[^>]+>','',str(posts[0]))
# Out:
# "\r\n\t\t\t\t\tThis is totally unbelievable !!   These two niggers were flown out of the country and allowed to eek and ook to the United Nations counsel about their thug felon sprog getting perforated by a human cop. \nIf this doesn't throw fire to the impending chimpouts, I don't know what will.  Can someone please help make sense of this bullshit ??\n\nhttp://www.cnn.com/2014/11/11/us/fer...iref=allsearch\n"

# %%
import gdata.youtube
import gdata.youtube.service

youtube_service = gdata.youtube.service.YouTubeService()

# randomly selected, mostly funny, some just stupid and lame
video_ids = ["6d26GGXkzR0", "21OH0wlkfbc", "PbeMwl_PA6A", "aSk0KDAc1gs"]
video_ids += ["JfXDAUIc9Xc", "hPPmLZ9dcRA", "frO6AC6wAc0", "0_fPV13lKm4"]
video_ids += ["nTasT5h0LEg", "A2syxXPR7xY", "MUaSxZf35O8", "wqXW-OMvpP0"]
video_ids += ["puHITWjTc_Q", "bHovtS_QWI4", "ao-9B8IV9_E", "xZlDb6vVsPw"]

for id in video_ids:
  for comment in youtube_service.GetYouTubeVideoCommentFeed(video_id = id).entry:
    print "..."
    print comment.content.text
    print "..."
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-63dc54e60540> in <module>()
#       1
# ----> 2 import gdata.youtube
#       3 import gdata.youtube.service
#       4
#       5 youtube_service = gdata.youtube.service.YouTubeService()
#
# ImportError: No module named gdata.youtube

# %%
import nltk
from nltk import bigrams
string = "I really like python, it's pretty awesome."
string_bigrams = bigrams(string)
print string_bigrams
# Out:
# <generator object bigrams at 0x109f38be0>

# %%
from nltk.util import ngrams
sentence = 'this is a foo bar sentences and i want to ngramize it'
n = 6
sixgrams = ngrams(sentence.split(), n)
for grams in sixgrams:
  print grams
# Out:
# ('this', 'is', 'a', 'foo', 'bar', 'sentences')
# ('is', 'a', 'foo', 'bar', 'sentences', 'and')
# ('a', 'foo', 'bar', 'sentences', 'and', 'i')
# ('foo', 'bar', 'sentences', 'and', 'i', 'want')
# ('bar', 'sentences', 'and', 'i', 'want', 'to')
# ('sentences', 'and', 'i', 'want', 'to', 'ngramize')
# ('and', 'i', 'want', 'to', 'ngramize', 'it')

# %%
text = {
 "kind": "youtube#commentThreadListResponse",
 "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/jckLFM2pXurTNzMKDU2h2cDNPQo\"",
 "nextPageToken": "Cg0QhdLPidOhxwIgACgBEhQIABDQoqK70qHHAhjoq6G_xZ3HAhgCIBQouKet4IT475w9",
 "pageInfo": {
  "resultsPerPage": 20
 },
 "items": [
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/BrjaekTsCI7oNzmynTpFXBXt91M\"",
   "id": "z12uwplybnenclswk04cfzao1kutwrf5aek",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/hz3eeC5bEXpJOnBFv5dYpzaY2qM\"",
     "id": "z12uwplybnenclswk04cfzao1kutwrf5aek",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "That Arab Braveheart-ish music is funny in and of itself.\ufeff",
      "authorDisplayName": "StephenAndrew777",
      "authorProfileImageUrl": "https://lh5.googleusercontent.com/-dMHhEFdZtCg/AAAAAAAAAAI/AAAAAAAAA88/9lIERAKqLFA/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/StephenAndrew777",
      "authorChannelId": {
       "value": "UCGOQIUserim99Yi7E5gxdnA"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/113914323532504097259",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T18:20:16.498Z",
      "updatedAt": "2015-08-11T18:20:16.498Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/Ad44k1lN3pvF_9ZG4DRmVChfCXM\"",
   "id": "z133xlwwgpnsthp4n04cglnjevmkt1rgzj0",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/gM0xGQW-T5vosjmruPpieUzCo1A\"",
     "id": "z133xlwwgpnsthp4n04cglnjevmkt1rgzj0",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "They were talking too fast\ufeff",
      "authorDisplayName": "Yao Kouassi",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-6hRT_5Y1Qxs/AAAAAAAAAAI/AAAAAAAAASM/IOVaLQHAp5U/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UChJ-ru4HQxotwY8FuC7rdFw",
      "authorChannelId": {
       "value": "UChJ-ru4HQxotwY8FuC7rdFw"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/104740301498369404481",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T17:43:25.940Z",
      "updatedAt": "2015-08-11T17:43:25.940Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/ehk0PSn7Mj3bMhEH9rILpySpZak\"",
   "id": "z133slqoqo3vctnoi04cgzvxskrgelwz2lk0k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/cJtqy1gs9DCOYSorSITSlpkLgcw\"",
     "id": "z133slqoqo3vctnoi04cgzvxskrgelwz2lk0k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "When I read the title for this skit, I thought he was gonna chop the dudes head off, and the guy was gonna keep on fighting and chop everyone elses head off, and they&#39;d be warriors without heads\ufeff",
      "authorDisplayName": "Viperphoenix",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/Viperphoenix",
      "authorChannelId": {
       "value": "UCikONbxSSfbJLyvFHMur-ew"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/114322999595053969524",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T16:38:58.140Z",
      "updatedAt": "2015-08-11T16:38:58.140Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/ycRN7Rr8xCZjfH8ZNmTdYJHNqso\"",
   "id": "z13djje4iqe3ddvtk23wvttqrqy1hvtbl04",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/RpmHca96YqGR-KpcutVAWcMpwsI\"",
     "id": "z13djje4iqe3ddvtk23wvttqrqy1hvtbl04",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "does this come in tabs too?\ufeff",
      "authorDisplayName": "TheAgentAssassin",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/TheAgentAssassin",
      "authorChannelId": {
       "value": "UCQFq3_W0RDU5ETW3fM5c4VA"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/114651427735001116200",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T09:42:56.152Z",
      "updatedAt": "2015-08-11T09:42:56.152Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/Klf1g-T6Py8MtD01vCsYACuzF2c\"",
   "id": "z13jz33gpn34c5rqa04cfzrjimv4ivyxaq40k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/E0qeTkWn-tSw9JH6CJa41LUkU9E\"",
     "id": "z13jz33gpn34c5rqa04cfzrjimv4ivyxaq40k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "Lol the last momment he posed a Foot Ball Stands\ufeff",
      "authorDisplayName": "John Marison",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCIyoo8qlSOg2vTWS3zu1guQ",
      "authorChannelId": {
       "value": "UCIyoo8qlSOg2vTWS3zu1guQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/107570835489985242514",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T07:42:14.322Z",
      "updatedAt": "2015-08-11T07:42:14.322Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/4L4WOrNv0BTOYOAZZm1ycjKhSgU\"",
   "id": "z125jrqzkrahc5o4p04ch5ibnqbmdlxhglo0k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/rEwvuv19yVXdimrbGkYqXYUauTg\"",
     "id": "z125jrqzkrahc5o4p04ch5ibnqbmdlxhglo0k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "I can&#39;t get over ow bad-ass those costumes are!\ufeff",
      "authorDisplayName": "Sunshine4695",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/Sunshine4695",
      "authorChannelId": {
       "value": "UC_wYZ6_4Ty6fe_zjzXHgIsg"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/114134302373621276368",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T05:50:02.339Z",
      "updatedAt": "2015-08-11T05:50:02.339Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/pt9fCZ-PvBAw3zcb_A26lDWeZ2k\"",
   "id": "z13ayfowgqqdg3isi232sfbqbpmvelbgv04",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/h0ACGYIv4Y7I36YoR5wA2CutwIU\"",
     "id": "z13ayfowgqqdg3isi232sfbqbpmvelbgv04",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "LOL, best one so far\ufeff",
      "authorDisplayName": "Fu Tang",
      "authorProfileImageUrl": "https://lh4.googleusercontent.com/-P3Mv8ne4ipY/AAAAAAAAAAI/AAAAAAAAAFo/LXFEm47HWK4/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/Futang808",
      "authorChannelId": {
       "value": "UCGS_ZLuPjPMKEpIZty93_qg"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/117939863228457765604",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T02:15:19.425Z",
      "updatedAt": "2015-08-11T02:15:19.425Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/0ys_sSPFeVUhR6bWizbpKToDgE4\"",
   "id": "z13rsfrwilzqypesu23sc1vjzpi2dhrjm04",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/fXJI4lT6jX3_DxB7wHfIYpU-UZ8\"",
     "id": "z13rsfrwilzqypesu23sc1vjzpi2dhrjm04",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "My favorite part is when they said &quot;AAAAAUUUUUUGGHGHHHHHH&quot;\ufeff",
      "authorDisplayName": "NoobAtLife",
      "authorProfileImageUrl": "https://lh5.googleusercontent.com/-iKemQD0buX4/AAAAAAAAAAI/AAAAAAAAAzU/RoNwVifmDuk/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UC2lRIn1oPmH4gfZAIaw3iSQ",
      "authorChannelId": {
       "value": "UC2lRIn1oPmH4gfZAIaw3iSQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/113390435954822704392",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T00:38:51.170Z",
      "updatedAt": "2015-08-11T00:38:51.170Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/qnUCsmXNVxtsTGTU9HlFqsbuiME\"",
   "id": "z13xcj0byw3jfvnmu23kelxqbrbxhf5ve",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/vhvu8kbmjuH0p95Anyk9bFutEAk\"",
     "id": "z13xcj0byw3jfvnmu23kelxqbrbxhf5ve",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "something that ISIS does on a daily basis\ufeff",
      "authorDisplayName": "TheMastorio",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/TheMastorio",
      "authorChannelId": {
       "value": "UCiUwhxsjGltTNLkX4OZBhDA"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/113238069881622186811",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-11T00:02:45.848Z",
      "updatedAt": "2015-08-11T00:02:45.848Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/rKuyw4FdAIgph509qJYJKNkAHl8\"",
   "id": "z13pvxgbkprutv4ly220gncqguf4ipmup",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/JtvM3zkxczT8rWc1OHhTEv8btqU\"",
     "id": "z13pvxgbkprutv4ly220gncqguf4ipmup",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "Jordan Peele actually looks really attractive in this barbarian getup lol\ufeff",
      "authorDisplayName": "Coral LB",
      "authorProfileImageUrl": "https://lh4.googleusercontent.com/-xU9AI61_QTI/AAAAAAAAAAI/AAAAAAAAAJo/vJxSv_wcBd8/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCB-FHwL14pevQTK4nhjLdFA",
      "authorChannelId": {
       "value": "UCB-FHwL14pevQTK4nhjLdFA"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/104967253101795402378",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T23:41:43.610Z",
      "updatedAt": "2015-08-10T23:41:43.610Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/u2JqHnooIDB_KufTsf_sBK6BXqk\"",
   "id": "z132vjlqvmn4tfwta22lwxgg1ojzhfgqp04",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/CY6T0JNhuCDjoAQ4pEtrcrI4LW4\"",
     "id": "z132vjlqvmn4tfwta22lwxgg1ojzhfgqp04",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "this would be better if they spoke a crude language with funny subtitles\ufeff",
      "authorDisplayName": "Buckley Brown",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/jaybeebee14",
      "authorChannelId": {
       "value": "UCHVhe1hMfwEJKC6XCkoRIUg"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/113028905066684698308",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T22:28:54.844Z",
      "updatedAt": "2015-08-10T22:28:54.844Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/QKbEBW0U0bufKp_gY7j3LsKaijU\"",
   "id": "z12ytpvwhmjkhdjdq234vrvi2lj0frlzw04",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/sDjtzGq-PFSrF7_pbvKHxIIqLns\"",
     "id": "z12ytpvwhmjkhdjdq234vrvi2lj0frlzw04",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "thought for sure he was rollin a J for a second there.\ufeff",
      "authorDisplayName": "Sir_Lagzalot",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/AnthoChannel",
      "authorChannelId": {
       "value": "UCIE9mPzPgJlxGt2rI3O0Zdg"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/116774448667365570378",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T21:40:28.056Z",
      "updatedAt": "2015-08-10T21:40:28.056Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/DWplALJGwYTj3GTl3wjHBmnacd4\"",
   "id": "z124h13q3nihudamd23wut0janaculqt2",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/Nggsx-rNxCQIg08D17cOjOVp-lg\"",
     "id": "z124h13q3nihudamd23wut0janaculqt2",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "peele eyes look bigger\ufeff",
      "authorDisplayName": "HungryBlackGuy",
      "authorProfileImageUrl": "https://lh6.googleusercontent.com/-8sNWlx1Am8U/AAAAAAAAAAI/AAAAAAAAAC4/a1WBhqVIls0/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/HungryBlackGuy",
      "authorChannelId": {
       "value": "UC4mvnzoLUo6p-i5t3KU7qwA"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/101454465165767727213",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T21:32:04.635Z",
      "updatedAt": "2015-08-10T21:32:04.635Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/seYtL-kalPBVG_2ecR2S6PfJCXc\"",
   "id": "z13jtttwfpjyjthgf04ccpr5wwygvlg5hkc0k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/unUnZLioWbXP8Pf40ggn84zSLyE\"",
     "id": "z13jtttwfpjyjthgf04ccpr5wwygvlg5hkc0k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "Trump campaign in a nutshell XD\ufeff",
      "authorDisplayName": "Giles Fredrickson",
      "authorProfileImageUrl": "https://lh4.googleusercontent.com/-qPWux8_Piu0/AAAAAAAAAAI/AAAAAAAAAKY/J3iqy76vDM4/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCvifzvJQGwb8yDl-ipxKsug",
      "authorChannelId": {
       "value": "UCvifzvJQGwb8yDl-ipxKsug"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/100107073745194692731",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T17:19:56.909Z",
      "updatedAt": "2015-08-10T17:19:56.909Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/ujzegJodqNBUZVSK7u0V-Ov7RA4\"",
   "id": "z12pyhuapkvxet5md22wddmpkleleztmx",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/rZ1fIugs4-2wIX8REWRRwGbutoA\"",
     "id": "z12pyhuapkvxet5md22wddmpkleleztmx",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "&quot;Football&quot;.\ufeff",
      "authorDisplayName": "Jo Momma",
      "authorProfileImageUrl": "https://lh6.googleusercontent.com/-oLNZnksiumc/AAAAAAAAAAI/AAAAAAAAACI/TM5RYA65tpY/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCrNwLxoqNmOe8ylLv7aV9gw",
      "authorChannelId": {
       "value": "UCrNwLxoqNmOe8ylLv7aV9gw"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/105847474243308841468",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T12:47:02.147Z",
      "updatedAt": "2015-08-10T12:47:02.147Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/GJCRfMMNUauAPLww8yKYEtyfX-Y\"",
   "id": "z12auxcqatfmdpqet23fznkzft2mhfdkb",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/3wmzKPgRu0sxqiG2tVNXY2NIYZ4\"",
     "id": "z12auxcqatfmdpqet23fznkzft2mhfdkb",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "I get it.\ufeff",
      "authorDisplayName": "alex commons",
      "authorProfileImageUrl": "https://lh4.googleusercontent.com/-rQauWE0KDPs/AAAAAAAAAAI/AAAAAAAABQU/svcy0t7lZ9w/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/liu3kang",
      "authorChannelId": {
       "value": "UC-Qlvr0qNm4i1Y7Cc2_8PSQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/106124177848893633637",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T12:30:39.503Z",
      "updatedAt": "2015-08-10T12:30:39.503Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/IUV9gc_dv8EOWfETajojWldaosI\"",
   "id": "z12lir5z4njxwz4ly23fxpqqyxehvps10",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/n4aFj7BGy_QYz7O2YaBX95201CU\"",
     "id": "z12lir5z4njxwz4ly23fxpqqyxehvps10",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "<a href=\"http://www.youtube.com/watch?v=rqYdxXfBKeY&amp;t=0m43s\">0:43</a> thug life \ufeff",
      "authorDisplayName": "Calvin Lin",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCo3SXtW4M5lEVr7MqtSpOlQ",
      "authorChannelId": {
       "value": "UCo3SXtW4M5lEVr7MqtSpOlQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/113939439610306569856",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T05:27:56.773Z",
      "updatedAt": "2015-08-10T05:27:56.773Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/PZ8Y25Hm3vfkdRY5sAlL6oleZbA\"",
   "id": "z13afrfrdvz0j1jxe04cc5wi4lziw3ox0rs0k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/WxIHdHDNlwxY1kd6DwUbexZ6LAw\"",
     "id": "z13afrfrdvz0j1jxe04cc5wi4lziw3ox0rs0k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "Ahhh Ahhhhh Uh AHHhhhhhHHh\ufeff",
      "authorDisplayName": "Halif Saban",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-v4EoJ1BcYMg/AAAAAAAAAAI/AAAAAAAAB3w/O_W9aICezeU/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/user/hahahalif",
      "authorChannelId": {
       "value": "UCiPFe-IQnepGxnOH2ISmEMQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/117857220891437355294",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T04:33:09.926Z",
      "updatedAt": "2015-08-10T04:33:09.926Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/uWLTduXQD26AYEZqtFla2F0K0dY\"",
   "id": "z13ffv0hwsiwst5og04ccnfgtzvjupzhcpw0k",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/1dg45Xb3D4dywbg58IpSaN83jxM\"",
     "id": "z13ffv0hwsiwst5og04ccnfgtzvjupzhcpw0k",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "AaaAArrrrgghhhh!... (i like the language they speak and learned to speak it in seconds because its a primitive language.)\ufeff",
      "authorDisplayName": "Brian Yacabalquiej",
      "authorProfileImageUrl": "https://lh3.googleusercontent.com/-XdUIqdMkCWA/AAAAAAAAAAI/AAAAAAAAAAA/4252rscbv5M/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCIG8Dptnv3jTmDNAxJExehQ",
      "authorChannelId": {
       "value": "UCIG8Dptnv3jTmDNAxJExehQ"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/110135530056102474328",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 2,
      "publishedAt": "2015-08-10T03:46:45.277Z",
      "updatedAt": "2015-08-10T03:46:45.277Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  },
  {

   "kind": "youtube#commentThread",
   "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/R7H22i1u6CmCL3Eh4pnXnW9pRoE\"",
   "id": "z12hdvpziwnjel1m0222fv0otqjgwl0er",
   "snippet": {
    "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
    "videoId": "rqYdxXfBKeY",
    "topLevelComment": {
     "kind": "youtube#comment",
     "etag": "\"iDqJ1j7zKs4x3o3ZsFlBOwgWAHU/slM2NX8SBK6tIZDf2BQBdjF3Rws\"",
     "id": "z12hdvpziwnjel1m0222fv0otqjgwl0er",
     "snippet": {
      "channelId": "UCUsN5ZwHx2kILm84-jPDeXw",
      "videoId": "rqYdxXfBKeY",
      "textDisplay": "It is said that decapitated heads are temporarily conscious after being severed from one&#39;s body. RAAAAAAAAAAAAAAAAAAAAH!!!!!!\ufeff",
      "authorDisplayName": "Infernoxe Kim",
      "authorProfileImageUrl": "https://lh4.googleusercontent.com/-YCQMc0_OoGw/AAAAAAAAAAI/AAAAAAAAADQ/uO4kzoO1aWM/photo.jpg?sz=50",
      "authorChannelUrl": "http://www.youtube.com/channel/UCh5DffauE5V4NJVNXsIm81Q",
      "authorChannelId": {
       "value": "UCh5DffauE5V4NJVNXsIm81Q"
      },
      "authorGoogleplusProfileUrl": "https://plus.google.com/100369497576567316338",
      "canRate": false,
      "viewerRating": "none",
      "likeCount": 0,
      "publishedAt": "2015-08-10T03:11:36.257Z",
      "updatedAt": "2015-08-10T03:11:36.257Z"
     }
    },
    "canReply": false,
    "totalReplyCount": 0,
    "isPublic": true
   }
  }
 ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d59631ee15cc> in <module>()
#      30       },
#      31       "authorGoogleplusProfileUrl": "https://plus.google.com/113914323532504097259",
# ---> 32       "canRate": false,
#      33       "viewerRating": "none",
#      34       "likeCount": 0,
#
# NameError: name 'false' is not defined
